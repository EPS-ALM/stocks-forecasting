# %%
import yfinance as yf
import pandas as pd
import datetime as dt
from statsmodels.tsa.seasonal import seasonal_decompose
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
from tqdm import tqdm
import random
plt.style.use('dark_background')

# %%
inicio = dt.date(2005, 1, 1)
final = dt.date(2024, 12, 1)

for acao in ['BRL=X', 'PETR4.SA', 'VALE3.SA', 'WEGE3.SA', 'GLD', '^GSPC']:
    df = yf.download(acao, inicio, final)#['Adj Close']
    df.columns = [header_pos[0] for header_pos in df.columns]
    df = df.reset_index()
    df.to_csv(f'../dados/raw/{acao}.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
inicio = dt.date(2005, 1, 1)
final = dt.date(2024, 12, 1)
acoes = ['BRL=X', 'PETR4.SA', 'VALE3.SA', 'WEGE3.SA', 'GLD']#, '^GSPC']
df = yf.download(acoes, inicio, final)['Adj Close']
df
# Out:
# [*********************100%***********************]  5 of 5 completed
# Ticker       BRL=X         GLD   PETR4.SA   VALE3.SA   WEGE3.SA
# Date
# 2005-01-03     NaN   43.020000   2.767463   8.210221   0.804532
# 2005-01-04     NaN   42.740002   2.734559   7.875673   0.804532
# 2005-01-05     NaN   42.669998   2.723982   7.820827   0.804532
# 2005-01-06     NaN   42.150002   2.732209   7.787922   0.804532
# 2005-01-07     NaN   41.840000   2.744254   7.996329   0.804532
# ...            ...         ...        ...        ...        ...
# 2024-11-25  5.7993  242.479996  39.180000  58.169998  52.150002
# 2024-11-26  5.7972  242.949997  39.130001  57.430000  52.779999
# 2024-11-27  5.8096  243.490005  38.990002  58.130001  52.110001
# 2024-11-28  5.9374         NaN  38.590000  57.529999  52.910000
# 2024-11-29  6.0139  245.589996  38.900002  58.779999  53.939999
#
# [5192 rows x 5 columns]

# %%
df.plot()
# Out:
# <Axes: xlabel='Date'>
